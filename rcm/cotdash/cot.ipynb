# %%
from rcm.cot import *

# %%
tickers
# Out:
#                direction     metric assettype  \
# ticker
# AACTDXTZ Index      Long  Contracts       NaN
# AACTXWQO Index     Short  Contracts       NaN
# AACTFFWD Index      Long  Contracts       NaN
# AACTTTSU Index     Short  Contracts       NaN
# AACTHKGO Index      Long  Contracts       NaN
# ...                  ...        ...       ...
# ZSCTXSKZ Index     Short  PercentOI       NaN
# ZSCTBTTU Index      Long  PercentOI       NaN
# ZSCTBNCI Index     Short  PercentOI       NaN
# ZSCTZLIW Index      Long  PercentOI       NaN
# ZSCTYOQM Index     Short  PercentOI       NaN
#
#                                              tradertype       activity  \
# ticker
# AACTDXTZ Index  Investment Firms or Credit Institutions  Risk Reducing
# AACTXWQO Index  Investment Firms or Credit Institutions  Risk Reducing
# AACTFFWD Index                         Investment Funds  Risk Reducing
# AACTTTSU Index                         Investment Funds  Risk Reducing
# ...

# %%
df
# Out:
#             px_last
# date
# 2006-06-13   105155
# 2006-06-20   100497
# 2006-06-27   107394
# 2006-07-04   118948
# 2006-07-11   127367
# ...             ...
# 2021-07-27   353278
# 2021-08-03   337498
# 2021-08-10   325266
# 2021-08-17   321982
# 2021-08-24   318887
#
# [794 rows x 1 columns]

# %%
tickers.iloc[1:5, [1]]
# Out:
#                    metric
# ticker
# AACTXWQO Index  Contracts
# AACTFFWD Index  Contracts
# AACTTTSU Index  Contracts
# AACTHKGO Index  Contracts

# %%
df2 = tickers.loc[['AACTHKGO Index', 'CFFDQMML Index', 'ZSCTXSKZ Index', 'ZSCTBTTU Index'], ['metric', 'description']]
df2
# Out:
#                    metric                                        description
# ticker
# AACTHKGO Index  Contracts  Alu Alloy LME COT Other Financial Firm Long Co...
# CFFDQMML Index  Contracts  CFTC NYMEX Crude Oil Managed Money Long Contra...
# ZSCTXSKZ Index  PercentOI  Zinc LME COT Other Financial Firm Short Pct of...
# ZSCTBTTU Index  PercentOI  Zinc LME COT Commercial Undertakings Long Pct ...

# %%
df2.to_dict('records')
# Out:
# [{'metric': 'Contracts',
#   'description': 'Alu Alloy LME COT Other Financial Firm Long Contracts Risk Reduct'},
#  {'metric': 'PercentOI',
#   'description': 'Zinc LME COT Other Financial Firm Short Pct of Open Interest Total'},
#  {'metric': 'PercentOI',
#   'description': 'Zinc LME COT Commercial Undertakings Long Pct of Open Interest Total'}]

# %%
print(df2.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>metric</th>
#       <th>description</th>
#     </tr>
#     <tr>
#       <th>ticker</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AACTHKGO Index</th>
#       <td>Contracts</td>
#       <td>Alu Alloy LME COT Other Financial Firm Long Contracts Risk Reduct</td>
#     </tr>
#     <tr>
#       <th>ZSCTXSKZ Index</th>
#       <td>PercentOI</td>
#       <td>Zinc LME COT Other Financial Firm Short Pct of Open Interest Total</td>
#     </tr>
#     <tr>
#       <th>ZSCTBTTU Index</th>
#       <td>PercentOI</td>
#       <td>Zinc LME COT Commercial Undertakings Long Pct of Open Interest Total</td>
#     </tr>
#   </tbody>
# </table>

# %%
df2
# Out:
#                    metric                                        description
# ticker
# AACTHKGO Index          X  Alu Alloy LME COT Other Financial Firm Long Co...
# ZSCTXSKZ Index          X  Zinc LME COT Other Financial Firm Short Pct of...
# ZSCTBTTU Index  PercentOI  Zinc LME COT Commercial Undertakings Long Pct ...
